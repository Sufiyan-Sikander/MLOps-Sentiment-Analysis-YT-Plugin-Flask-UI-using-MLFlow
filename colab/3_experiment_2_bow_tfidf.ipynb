# %%
pip install mlflow boto3 awscli
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mlflow in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (3.14.0)
# Requirement already satisfied: boto3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (1.35.36)
# Collecting awscli
#   Using cached awscli-1.45.45-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: mlflow-skinny==3.14.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.14.0)
# Requirement already satisfied: mlflow-tracing==3.14.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.14.0)
# Requirement already satisfied: Flask-CORS<7 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (6.0.5)
# Requirement already satisfied: Flask<4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.14.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (1.18.5)
# Requirement already satisfied: cryptography<49,>=43.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (48.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (7.2.0)
# Requirement already satisfied: graphene<4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<4,>=2.5.4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.2.1)
# Requirement already satisfied: matplotlib<4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.11.0)
# Requirement already satisfied: numpy<3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (2.4.6)
# Requirement already satisfied: pandas<3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (24.0.0)
# Requirement already satisfied: scikit-learn<2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (1.9.0)
# Requirement already satisfied: scipy<2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (1.17.1)
# Requirement already satisfied: skops<1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (2.0.51)
# Requirement already satisfied: waitress<4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<8,>=5.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (8.4.2)
# Requirement already satisfied: cloudpickle<4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.120.0)
# Requirement already satisfied: fastapi<1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.139.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.50)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (9.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: packaging<27 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (26.2)
# Requirement already satisfied: protobuf<8,>=3.12.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (6.33.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (2.13.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (2.34.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.5.5)
# Requirement already satisfied: starlette<2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (4.16.0)
# Requirement already satisfied: uvicorn<1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.51.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.36 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from boto3) (1.35.93)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from boto3) (0.10.4)
#   Using cached awscli-1.45.44-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.43-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.42-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.41-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.40-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.39-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.38-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.37-py3-none-any.whl (4.7 MB)
#   Using cached awscli-1.45.36-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.35-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.34-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.33-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.32-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.31-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.30-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.29-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.28-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.27-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.26-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.25-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.24-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.23-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.22-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.21-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.20-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.19-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.18-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.17-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.16-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.15-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.14-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.13-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.12-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.11-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.10-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.9-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.8-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.7-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.6-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.5-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.4-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.3-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.2-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.1-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.45.0-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.87-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.86-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.85-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.84-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.83-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.82-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.81-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.80-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.79-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.78-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.77-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.76-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.75-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.74-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.73-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.72-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.71-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.70-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.69-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.68-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.67-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.66-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.65-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.64-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.63-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.62-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.61-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.60-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.59-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.58-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.57-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.56-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.55-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.54-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.53-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.52-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.51-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.50-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.49-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.48-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.47-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.46-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.45-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.44-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.43-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.42-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.41-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.40-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.39-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.38-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.37-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.36-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.35-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.34-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.33-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.32-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.31-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.30-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.29-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.28-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.27-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.26-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.25-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.24-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.23-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.22-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.21-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.20-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.19-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.18-py3-none-any.whl (4.6 MB)
#   Using cached awscli-1.44.17-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.44.16-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 794.5 kB/s eta 0:00:00
#   Using cached awscli-1.44.15-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.44.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 927.7 kB/s eta 0:00:00
#   Downloading awscli-1.44.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 967.3 kB/s eta 0:00:00
#   Using cached awscli-1.44.12-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.44.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.44.10-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.44.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.44.8-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.44.7-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.44.6-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.44.5-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.44.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.44.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.44.2-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 715.5 kB/s eta 0:00:00
#   Downloading awscli-1.44.1-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 946.3 kB/s eta 0:00:00
#   Downloading awscli-1.44.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 970.9 kB/s eta 0:00:00
#   Downloading awscli-1.43.15-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 658.9 kB/s eta 0:00:00
#   Downloading awscli-1.43.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 697.7 kB/s eta 0:00:00
#   Downloading awscli-1.43.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 982.8 kB/s eta 0:00:00
#   Downloading awscli-1.43.12-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 847.7 kB/s eta 0:00:00
#   Downloading awscli-1.43.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 857.6 kB/s eta 0:00:00
#   Using cached awscli-1.43.10-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.43.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 828.5 kB/s eta 0:00:00
#   Downloading awscli-1.43.8-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 890.8 kB/s eta 0:00:00
#   Using cached awscli-1.43.7-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.43.6-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 595.2 kB/s eta 0:00:00
#   Downloading awscli-1.43.5-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 833.2 kB/s eta 0:00:00
#   Downloading awscli-1.43.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 584.5 kB/s eta 0:00:00
#   Downloading awscli-1.43.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.43.2-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 838.0 kB/s eta 0:00:00
#   Downloading awscli-1.43.1-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 933.1 kB/s eta 0:00:00
#   Downloading awscli-1.43.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 960.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.76-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 877.6 kB/s eta 0:00:00
#   Downloading awscli-1.42.75-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 797.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.74-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 814.8 kB/s eta 0:00:00
#   Downloading awscli-1.42.73-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 799.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.72-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 835.5 kB/s eta 0:00:00
#   Using cached awscli-1.42.71-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.42.70-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 762.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.69-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 609.8 kB/s eta 0:00:00
#   Downloading awscli-1.42.68-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 542.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.67-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 547.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.66-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 583.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.65-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 634.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.64-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 618.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.63-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 711.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.62-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 603.6 kB/s eta 0:00:00
#   Downloading awscli-1.42.61-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 999.2 kB/s eta 0:00:00
#   Downloading awscli-1.42.60-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 917.2 kB/s eta 0:00:00
#   Downloading awscli-1.42.59-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 823.5 kB/s eta 0:00:00
#   Downloading awscli-1.42.58-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 537.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.57-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 583.3 kB/s eta 0:00:00
#   Using cached awscli-1.42.56-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.42.55-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 533.2 kB/s eta 0:00:00
#   Downloading awscli-1.42.54-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 489.5 kB/s eta 0:00:00
#   Using cached awscli-1.42.53-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.42.52-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 446.9 kB/s eta 0:00:00
#   Downloading awscli-1.42.51-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 703.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.50-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 522.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.49-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 653.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.48-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 678.9 kB/s eta 0:00:00
#   Downloading awscli-1.42.47-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 610.8 kB/s eta 0:00:00
#   Downloading awscli-1.42.46-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 827.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.45-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 796.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.44-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 825.1 kB/s eta 0:00:00
#   Using cached awscli-1.42.43-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.42.42-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 728.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.41-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 683.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.40-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 894.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.39-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Using cached awscli-1.42.38-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.42.37-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.36-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 816.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.35-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.42.34-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 818.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.33-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 942.6 kB/s eta 0:00:00
#   Downloading awscli-1.42.32-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.42.31-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.30-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.42.29-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.28-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.27-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 989.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.26-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 973.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.25-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.24-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 970.1 kB/s eta 0:00:00
#   Downloading awscli-1.42.23-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.22-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 916.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.21-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 818.2 kB/s eta 0:00:00
#   Downloading awscli-1.42.20-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 983.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.19-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 976.4 kB/s eta 0:00:00
#   Downloading awscli-1.42.18-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 862.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.17-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.16-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.15-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.14-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.13-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Using cached awscli-1.42.12-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.42.11-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.10-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 743.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.9-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 666.3 kB/s eta 0:00:00
#   Downloading awscli-1.42.8-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.7-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.6-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.5-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 981.0 kB/s eta 0:00:00
#   Downloading awscli-1.42.4-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.3-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.42.2-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.42.1-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 974.7 kB/s eta 0:00:00
#   Downloading awscli-1.42.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 918.2 kB/s eta 0:00:00
#   Downloading awscli-1.41.17-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 958.8 kB/s eta 0:00:00
#   Downloading awscli-1.41.16-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 938.0 kB/s eta 0:00:00
#   Downloading awscli-1.41.15-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 971.1 kB/s eta 0:00:00
#   Downloading awscli-1.41.14-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.13-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.12-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.41.11-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.41.10-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.9-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.8-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.7-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 981.2 kB/s eta 0:00:00
#   Downloading awscli-1.41.6-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 935.4 kB/s eta 0:00:00
#   Downloading awscli-1.41.5-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 904.2 kB/s eta 0:00:00
#   Downloading awscli-1.41.4-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 870.2 kB/s eta 0:00:00
#   Downloading awscli-1.41.3-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 953.1 kB/s eta 0:00:00
#   Downloading awscli-1.41.2-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.41.1-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 968.4 kB/s eta 0:00:00
#   Downloading awscli-1.41.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 845.7 kB/s eta 0:00:00
#   Downloading awscli-1.40.45-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 904.2 kB/s eta 0:00:00
#   Downloading awscli-1.40.44-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 904.2 kB/s eta 0:00:00
#   Downloading awscli-1.40.43-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 885.2 kB/s eta 0:00:00
#   Downloading awscli-1.40.42-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 974.3 kB/s eta 0:00:00
#   Downloading awscli-1.40.41-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 766.9 kB/s eta 0:00:00
#   Downloading awscli-1.40.40-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 864.0 kB/s eta 0:00:00
#   Downloading awscli-1.40.39-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.40.38-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.37-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.36-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.35-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.40.34-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.33-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.32-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.31-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.30-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 994.3 kB/s eta 0:00:00
#   Downloading awscli-1.40.29-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.28-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.40.27-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 901.3 kB/s eta 0:00:00
#   Downloading awscli-1.40.26-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 872.3 kB/s eta 0:00:00
#   Using cached awscli-1.40.25-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.40.24-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 802.0 kB/s eta 0:00:00
#   Using cached awscli-1.40.23-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.40.22-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 874.9 kB/s eta 0:00:00
#   Downloading awscli-1.40.21-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 949.9 kB/s eta 0:00:00
#   Downloading awscli-1.40.20-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 963.7 kB/s eta 0:00:00
#   Using cached awscli-1.40.19-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.40.18-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 982.8 kB/s eta 0:00:00
#   Downloading awscli-1.40.17-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 957.6 kB/s eta 0:00:00
#   Downloading awscli-1.40.16-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 919.0 kB/s eta 0:00:00
#   Using cached awscli-1.40.15-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.40.14-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.40.13-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 982.8 kB/s eta 0:00:00
#   Downloading awscli-1.40.12-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 992.5 kB/s eta 0:00:00
#   Downloading awscli-1.40.11-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.40.10-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
#   Downloading awscli-1.40.9-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
#   Downloading awscli-1.40.8-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.40.7-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.6-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.5-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.4-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.3-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.2-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.1-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.40.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.39.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.38-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.37-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.36-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.35-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.34-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 985.9 kB/s eta 0:00:00
#   Downloading awscli-1.38.33-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.32-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.31-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.30-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Using cached awscli-1.38.29-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.38.28-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.27-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.26-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.38.25-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.24-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.23-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.22-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.21-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.20-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 976.0 kB/s eta 0:00:00
#   Downloading awscli-1.38.19-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 976.0 kB/s eta 0:00:00
#   Downloading awscli-1.38.18-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
#   Using cached awscli-1.38.17-py3-none-any.whl (4.7 MB)
#   Downloading awscli-1.38.16-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.15-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.12-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.10-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Using cached awscli-1.38.8-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.38.7-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.6-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.5-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.2-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.1-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.26-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.25-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.24-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.23-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.22-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.21-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.20-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.19-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.18-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.17-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 959.0 kB/s eta 0:00:00
#   Downloading awscli-1.37.16-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Using cached awscli-1.37.15-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.12-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.10-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Using cached awscli-1.37.8-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.7-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.6-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.5-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.37.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.2-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.37.1-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.37.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.36.40-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.5 MB/s eta 0:00:00
# Collecting botocore<1.36.0,>=1.35.36
#   Using cached botocore-1.35.99-py3-none-any.whl (13.3 MB)
# Collecting docutils<0.17,>=0.10
#   Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from awscli) (0.4.6)
# Collecting rsa<4.8,>=3.1.2
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.24.2)
# Requirement already satisfied: Mako in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from cryptography<49,>=43.0.0->mlflow) (2.1.0)
# Requirement already satisfied: pywin32>=304 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (312)
# Requirement already satisfied: blinker>=1.9.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.1.8)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (1.5.0)
# ...
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
#   Downloading awscli-1.38.21-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.38.20-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
#   Downloading awscli-1.38.19-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.5 MB/s eta 0:00:00
#   Downloading awscli-1.38.18-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
#   Downloading awscli-1.38.17-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.38.16-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.38.15-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.3 MB/s eta 0:00:00
#   Downloading awscli-1.38.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.12-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.2 MB/s eta 0:00:00
#   Downloading awscli-1.38.10-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.8-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.7-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
#   Downloading awscli-1.38.6-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.38.5-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 977.0 kB/s eta 0:00:00
#   Downloading awscli-1.38.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 862.4 kB/s eta 0:00:00
#   Downloading awscli-1.38.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 885.5 kB/s eta 0:00:00
#   Downloading awscli-1.38.2-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 948.4 kB/s eta 0:00:00
#   Using cached awscli-1.38.1-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.38.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 956.0 kB/s eta 0:00:00
#   Downloading awscli-1.37.26-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 994.7 kB/s eta 0:00:00
#   Downloading awscli-1.37.25-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 984.6 kB/s eta 0:00:00
#   Downloading awscli-1.37.24-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 971.7 kB/s eta 0:00:00
#   Downloading awscli-1.37.23-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.22-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.21-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.20-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.19-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 965.4 kB/s eta 0:00:00
#   Using cached awscli-1.37.18-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.17-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 898.0 kB/s eta 0:00:00
#   Downloading awscli-1.37.16-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 965.4 kB/s eta 0:00:00
#   Using cached awscli-1.37.15-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.14-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.13-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 971.7 kB/s eta 0:00:00
#   Downloading awscli-1.37.12-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 962.0 kB/s eta 0:00:00
#   Downloading awscli-1.37.11-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Using cached awscli-1.37.10-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.9-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.8-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.7-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.37.6-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 891.9 kB/s eta 0:00:00
#   Using cached awscli-1.37.5-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.4-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 830.8 kB/s eta 0:00:00
#   Downloading awscli-1.37.3-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 867.9 kB/s eta 0:00:00
#   Using cached awscli-1.37.2-py3-none-any.whl (4.6 MB)
#   Downloading awscli-1.37.1-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 958.0 kB/s eta 0:00:00
#   Downloading awscli-1.37.0-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.0 MB/s eta 0:00:00
#   Downloading awscli-1.36.40-py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.3 MB/s eta 0:00:00
# Collecting botocore<1.36.0,>=1.35.36
#   Using cached botocore-1.35.99-py3-none-any.whl (13.3 MB)
# Collecting docutils<0.17,>=0.10
#   Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from awscli) (0.4.6)
# Collecting rsa<4.8,>=3.1.2
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.24.2)
# Requirement already satisfied: Mako in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from cryptography<49,>=43.0.0->mlflow) (2.1.0)
# Requirement already satisfied: pywin32>=304 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (312)
# Requirement already satisfied: blinker>=1.9.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from Flask<4->mlflow) (3.1.8)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (1.5.0)
# Requirement already satisfied: pillow>=9 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from pandas<3->mlflow) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from pandas<3->mlflow) (2026.3)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.4)
# Requirement already satisfied: joblib>=1.4.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from scikit-learn<2->mlflow) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from skops<1->mlflow) (3.18.0)
# Requirement already satisfied: greenlet>=1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.5.3)
# Requirement already satisfied: pycparser in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: google-auth~=2.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (2.55.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow) (0.64b0)
# Requirement already satisfied: wcwidth>=0.3.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (2.46.4)
# Requirement already satisfied: six>=1.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.36->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (2026.6.17)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from starlette<2->mlflow-skinny==3.14.0->mlflow) (4.14.1)
# Requirement already satisfied: h11>=0.8 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from uvicorn<1->mlflow-skinny==3.14.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\coding\mlops-youtube-sentiment-main\myenv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Installing collected packages: rsa, docutils, botocore, awscli
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.93
#     Uninstalling botocore-1.35.93:
#       Successfully uninstalled botocore-1.35.93
# Successfully installed awscli-1.36.40 botocore-1.35.99 docutils-0.16 rsa-4.7.2
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/docutils/
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.17.0 requires botocore<1.35.94,>=1.35.74, but you have botocore 1.35.99 which is incompatible.
#
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !aws configure
# Out:
# 'aws' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 2 - BoW vs TfIdf")
# Out:
# 2025/07/22 00:13:07 INFO mlflow.tracking.fluent: Experiment with name 'Exp 2 - BoW vs TfIdf' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-buckets-25/703614231131416294', creation_time=1753143187758, experiment_id='703614231131416294', last_update_time=1753143187758, lifecycle_stage='active', name='Exp 2 - BoW vs TfIdf', tags={}>

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
df = pd.read_csv('/content/reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Function to run the experiment
def run_experiment(vectorizer_type, ngram_range, vectorizer_max_features, vectorizer_name):
    # Step 2: Vectorization
    if vectorizer_type == "BoW":
        vectorizer = CountVectorizer(ngram_range=ngram_range, max_features=vectorizer_max_features)
    else:
        vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=vectorizer_max_features)

    X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)

    # Step 4: Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName", f"{vectorizer_name}_{ngram_range}_RandomForest")
        mlflow.set_tag("experiment_type", "feature_engineering")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag("description", f"RandomForest with {vectorizer_name}, ngram_range={ngram_range}, max_features={vectorizer_max_features}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", vectorizer_type)
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", vectorizer_max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)

        # Initialize and train the model
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(X_train, y_train)

        # Step 5: Make predictions and log metrics
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: {vectorizer_name}, {ngram_range}")
        plt.savefig("confusion_matrix.png")
        mlflow.log_artifact("confusion_matrix.png")
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(model, f"random_forest_model_{vectorizer_name}_{ngram_range}")

# Step 6: Run experiments for BoW and TF-IDF with different n-grams
ngram_ranges = [(1, 1), (1, 2), (1, 3)]  # unigrams, bigrams, trigrams
max_features = 5000  # Example max feature size

for ngram_range in ngram_ranges:
    # BoW Experiments
    run_experiment("BoW", ngram_range, max_features, vectorizer_name="BoW")

    # TF-IDF Experiments
    run_experiment("TF-IDF", ngram_range, max_features, vectorizer_name="TF-IDF")
# Out:
# 2025/07/22 00:26:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:26:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run BoW_(1, 1)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/fe7fdedb8dd84e4aa9462f4fcc2a22e1
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
# 2025/07/22 00:27:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:28:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TF-IDF_(1, 1)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/e37733db80e343339629ce994a6a0a51
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
# 2025/07/22 00:28:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:29:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run BoW_(1, 2)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/64b87932cb27424780105409d73339ef
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
# 2025/07/22 00:30:08 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:30:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TF-IDF_(1, 2)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/10b1dd63aa674cb1b0581d335d53f370
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
# 2025/07/22 00:31:21 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:31:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run BoW_(1, 3)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/b9ef8403e2bf49deb76221823bd1fe3b
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
# 2025/07/22 00:32:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/22 00:32:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TF-IDF_(1, 3)_RandomForest at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294/runs/d09b951e6eb148beadf71102113d5c00
# 🧪 View experiment at: http://ec2-18-133-28-185.eu-west-2.compute.amazonaws.com:5000/#/experiments/703614231131416294
